# %%
import pandas as pd
import numpy as np
from ast import literal_eval
from collections import defaultdict, Counter

# %%
df = pd.read_csv("Amended_Correct_No_IR.csv")
df["Year"] = df["Date"].apply(pd.to_datetime).apply(lambda x: x.year)
df
# Out:
#        Unnamed: 0  Unnamed: 0.1  index                     Keyword  \
# 0              14            21     21                 hurdle rate
# 1              24            36     36               discount rate
# 2              33            46     46            return on assets
# 3              40            57     57  return on invested capital
# 4              70            89     89            return on assets
# ...           ...           ...    ...                         ...
# 60640      784390       1330247    150             cost of capital
# 60641      784391       1330250    153                        ROIC
# 60642      784396       1330255    158                         OCC
# 60643      784397       1330256    159                        ROIC
# 60644      784399       1330258    161  return on invested capital
#
#                                                     Para    Report PPV TOC  \
# 0      THE CALLER: Okay. In terms of the margins, the...   8009953   N   N
# 1      MR. ANTHONY RUGGIERO: Return assumptions at th...   8009887   N   N
# 2       additional products that have entered Phase I...   8009956   N   N
# 3       11.54 cents per square foot, while capital on...   8009957   N   N
# 4       reserves in the Life Company and OFC Capital....   8009969   N   N
# ...                                                  ...       ...  ..  ..
# 60640  Shazad G. Dada - United Bank Limited - Preside...  71557135   N   Y
# 60641  So to close out this section, 2 days ago, in o...  71557147   N   Y
# 60642   Ashish Masih - Encore Capital Group, Inc. - P...  71557147   N   Y
# 60643  So yes, absolutely. We have also looked at acq...  71568653   N   Y
# 60644  Daniel J. Shook - IMI plc - Finance Director &...  71568653   N   Y
#
#                                                    Title  \
# 0      VARCO INTERNATIONAL INCORPORATED (VRC) - Q2 20...
# 1      OLIN CORPORATION (OLN) - Q2 2002 FINANCIAL REL...
# 2      SEROLOGICALS CORP. (SERO) - Q2 2002 FINANCIAL ...
# 3      BRANDYWINE REALTY TRUST (BDN) - Q2 2002 EARNIN...
# 4      ALFA CORPORATION (ALFA) - Q2 2002 FINANCIAL RE...
# ...                                                  ...
# 60640                                UNITED BANK LIMITED
# 60641                           ENCORE CAPITAL GROUP INC
# 60642                           ENCORE CAPITAL GROUP INC
# 60643                                            IMI PLC
# 60644                                            IMI PLC
#
#                                                 Subtitle  ...   Analyst  \
# 0                                                         ...  FDFN.COM
# 1                                                         ...  FDFN.COM
# 2                                                         ...  FDFN.COM
# 3                                                         ...  FDFN.COM
# 4                                                         ...  FDFN.COM
# ...                                                  ...  ...       ...
# 60640  UBL.PSX - Event Transcript of United Bank Ltd ...  ...      ANON
# 60641  ECPG.OQ - Event Transcript of Encore Capital G...  ...      ANON
# 60642  ECPG.OQ - Event Transcript of Encore Capital G...  ...      ANON
# 60643  IMI.L - Event Transcript of IMI PLC conference...  ...      ANON
# 60644  IMI.L - Event Transcript of IMI PLC conference...  ...      ANON
#
#        Language Collection                                               Call  \
# 0       English        INV   \n \n\nTHE OPERATOR:\nGood morning and welcom...
# 1       English        INV   \n \n\nTHE OPERATOR:\nWelcome to the Olin Cor...
# 2       English        INV   \n \n\nTHE OPERATOR:\nGood day everyone and w...
# 3       English        INV   \n \n\nTHE OPERATOR:\nGood day ladies and gen...
# 4       English        INV   \n \n\nTHE OPERATOR:\nGood morning and welcom...
# ...         ...        ...                                                ...
# 60640   English        INV   \n CORPORATE PARTICIPANTS\nAameer Mustaaly Ka...
# 60641   English        INV   \n CORPORATE PARTICIPANTS\nAshish Masih Encor...
# 60642   English        INV   \n CORPORATE PARTICIPANTS\nAshish Masih Encor...
# 60643   English        INV   \n CORPORATE PARTICIPANTS\nDaniel J. Shook IM...
# 60644   English        INV   \n CORPORATE PARTICIPANTS\nDaniel J. Shook IM...
#
#                           File HasNumber Correct NumberOfOccurences  \
# 0      20020726-20020729_4.csv       1.0    True                  1
# 1      20020726-20020729_4.csv       1.0    True                  1
# 2      20020726-20020729_4.csv       1.0    True                  1
# 3      20020726-20020729_4.csv       1.0    True                  2
# 4      20020726-20020729_4.csv       1.0    True                  1
# ...                        ...       ...     ...                ...
# 60640  20210225-20210301_9.csv       1.0    True                  1
# 60641  20210225-20210301_9.csv       1.0    True                  1
# 60642  20210225-20210301_9.csv       1.0    True                  2
# 60643  20210225-20210301_9.csv       1.0    True                  1
# 60644  20210225-20210301_9.csv       1.0    True                  1
#
#                                 List_Keywords  Year
# 0                             ['hurdle rate']  2002
# 1                           ['discount rate']  2002
# 2                        ['return on assets']  2002
# 3              ['return on invested capital']  2002
# 4                        ['return on assets']  2002
# ...                                       ...   ...
# 60640                     ['cost of capital']  2021
# 60641  ['ROIC', 'return on invested capital']  2021
# 60642                                 ['OCC']  2021
# 60643             ['cost of capital', 'ROIC']  2021
# 60644          ['return on invested capital']  2021
#
# [60645 rows x 24 columns]

# %%
keywords = pd.read_csv("keyterms.txt", sep = "\t", header = None)
keywords
# Out:
#                                    0
# 0                               ROIC
# 1         return on invested capital
# 2                                IRR
# 3            internal rate of return
# 4                     hurdle premium
# 5                      discount rate
# 6        opportunity cost of capital
# 7                                OCC
# 8                       fudge factor
# 9                    required return
# 10           required rate of return
# 11                  require a return
# 12                   expected return
# 13           expected rate of return
# 14                   expect a return
# 15                              CAPM
# 16       capital asset pricing model
# 17                     interest rate
# 18          weighted cost of capital
# 19  weighted average cost of capital
# 20                              WACC
# 21                       hurdle rate
# 22                   cost of capital
# 23                    cost of equity
# 24                      cost of debt
# 25                  return on assets
# 26              return on net assets

# %%
d = defaultdict(int)
d["hurdle rate"] = 5
d["cost of equity"] = 4
d["cost of capital"] = 3
d["IRR"] = 2
d["internal rate of return"] = 2
d["ROIC"] = 1
d["return on invested capital"] = 1
keywords["priority"] = keywords[0].apply(lambda x: d[x])
keywords = keywords[keywords[0] != "interest rate"]
keywords["lower"] = keywords[0].str.lower()
priority_dict = dict(keywords.set_index(0)["priority"])
priority_dict
# Out:
# <ipython-input-9-3ea9d71f6da1>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   keywords["lower"] = keywords[0].str.lower()
# {'ROIC': 1,
#  'return on invested capital': 1,
#  'IRR': 2,
#  'internal rate of return': 2,
#  'hurdle premium': 0,
#  'discount rate': 0,
#  'opportunity cost of capital': 0,
#  'OCC': 0,
#  'fudge factor': 0,
#  'required return': 0,
#  'required rate of return': 0,
#  'require a return': 0,
#  'expected return': 0,
#  'expected rate of return': 0,
#  'expect a return': 0,
#  'CAPM': 0,
#  'capital asset pricing model': 0,
#  'weighted cost of capital': 0,
#  'weighted average cost of capital': 0,
#  'WACC': 0,
#  'hurdle rate': 5,
#  'cost of capital': 3,
#  'cost of equity': 4,
#  'cost of debt': 0,
#  'return on assets': 0,
#  'return on net assets': 0}

# %%
def choose_according_to_priority(l, keywords_priority_dict):
    t = []
    if len(l) == 1:
        main_keyword = l[0]
    else:
        for k in l:
            t.append(keywords_priority_dict[k])
        highest_priority_index = pd.Series(t).idxmax()
        main_keyword = l[highest_priority_index]
    return main_keyword

df["List_Keywords"] = df["List_Keywords"].apply(literal_eval)
df["Highest_Priority_Keyword"] = df["List_Keywords"].apply(lambda x: choose_according_to_priority(x, priority_dict))
df["Keyword_Priority_Value"] = df["Highest_Priority_Keyword"].apply(lambda x: priority_dict[x])
df
# Out:
#        Unnamed: 0  Unnamed: 0.1  index                     Keyword  \
# 0              14            21     21                 hurdle rate
# 1              24            36     36               discount rate
# 2              33            46     46            return on assets
# 3              40            57     57  return on invested capital
# 4              70            89     89            return on assets
# ...           ...           ...    ...                         ...
# 60640      784390       1330247    150             cost of capital
# 60641      784391       1330250    153                        ROIC
# 60642      784396       1330255    158                         OCC
# 60643      784397       1330256    159                        ROIC
# 60644      784399       1330258    161  return on invested capital
#
#                                                     Para    Report PPV TOC  \
# 0      THE CALLER: Okay. In terms of the margins, the...   8009953   N   N
# 1      MR. ANTHONY RUGGIERO: Return assumptions at th...   8009887   N   N
# 2       additional products that have entered Phase I...   8009956   N   N
# 3       11.54 cents per square foot, while capital on...   8009957   N   N
# 4       reserves in the Life Company and OFC Capital....   8009969   N   N
# ...                                                  ...       ...  ..  ..
# 60640  Shazad G. Dada - United Bank Limited - Preside...  71557135   N   Y
# 60641  So to close out this section, 2 days ago, in o...  71557147   N   Y
# 60642   Ashish Masih - Encore Capital Group, Inc. - P...  71557147   N   Y
# 60643  So yes, absolutely. We have also looked at acq...  71568653   N   Y
# 60644  Daniel J. Shook - IMI plc - Finance Director &...  71568653   N   Y
#
#                                                    Title  \
# 0      VARCO INTERNATIONAL INCORPORATED (VRC) - Q2 20...
# 1      OLIN CORPORATION (OLN) - Q2 2002 FINANCIAL REL...
# 2      SEROLOGICALS CORP. (SERO) - Q2 2002 FINANCIAL ...
# 3      BRANDYWINE REALTY TRUST (BDN) - Q2 2002 EARNIN...
# 4      ALFA CORPORATION (ALFA) - Q2 2002 FINANCIAL RE...
# ...                                                  ...
# 60640                                UNITED BANK LIMITED
# 60641                           ENCORE CAPITAL GROUP INC
# 60642                           ENCORE CAPITAL GROUP INC
# 60643                                            IMI PLC
# 60644                                            IMI PLC
#
#                                                 Subtitle  ... Collection  \
# 0                                                         ...        INV
# 1                                                         ...        INV
# 2                                                         ...        INV
# 3                                                         ...        INV
# 4                                                         ...        INV
# ...                                                  ...  ...        ...
# 60640  UBL.PSX - Event Transcript of United Bank Ltd ...  ...        INV
# 60641  ECPG.OQ - Event Transcript of Encore Capital G...  ...        INV
# 60642  ECPG.OQ - Event Transcript of Encore Capital G...  ...        INV
# 60643  IMI.L - Event Transcript of IMI PLC conference...  ...        INV
# 60644  IMI.L - Event Transcript of IMI PLC conference...  ...        INV
#
#                                                     Call  \
# 0       \n \n\nTHE OPERATOR:\nGood morning and welcom...
# 1       \n \n\nTHE OPERATOR:\nWelcome to the Olin Cor...
# 2       \n \n\nTHE OPERATOR:\nGood day everyone and w...
# 3       \n \n\nTHE OPERATOR:\nGood day ladies and gen...
# 4       \n \n\nTHE OPERATOR:\nGood morning and welcom...
# ...                                                  ...
# 60640   \n CORPORATE PARTICIPANTS\nAameer Mustaaly Ka...
# 60641   \n CORPORATE PARTICIPANTS\nAshish Masih Encor...
# 60642   \n CORPORATE PARTICIPANTS\nAshish Masih Encor...
# 60643   \n CORPORATE PARTICIPANTS\nDaniel J. Shook IM...
# 60644   \n CORPORATE PARTICIPANTS\nDaniel J. Shook IM...
#
#                           File HasNumber Correct NumberOfOccurences  \
# 0      20020726-20020729_4.csv       1.0    True                  1
# 1      20020726-20020729_4.csv       1.0    True                  1
# 2      20020726-20020729_4.csv       1.0    True                  1
# 3      20020726-20020729_4.csv       1.0    True                  2
# 4      20020726-20020729_4.csv       1.0    True                  1
# ...                        ...       ...     ...                ...
# 60640  20210225-20210301_9.csv       1.0    True                  1
# 60641  20210225-20210301_9.csv       1.0    True                  1
# 60642  20210225-20210301_9.csv       1.0    True                  2
# 60643  20210225-20210301_9.csv       1.0    True                  1
# 60644  20210225-20210301_9.csv       1.0    True                  1
#
#                             List_Keywords  Year    Highest_Priority_Keyword  \
# 0                           [hurdle rate]  2002                 hurdle rate
# 1                         [discount rate]  2002               discount rate
# 2                      [return on assets]  2002            return on assets
# 3            [return on invested capital]  2002  return on invested capital
# 4                      [return on assets]  2002            return on assets
# ...                                   ...   ...                         ...
# 60640                   [cost of capital]  2021             cost of capital
# 60641  [ROIC, return on invested capital]  2021                        ROIC
# 60642                               [OCC]  2021                         OCC
# 60643             [cost of capital, ROIC]  2021             cost of capital
# 60644        [return on invested capital]  2021  return on invested capital
#
#        Keyword_Priority_Value
# 0                           5
# 1                           0
# 2                           0
# 3                           1
# 4                           0
# ...                       ...
# 60640                       3
# 60641                       1
# 60642                       0
# 60643                       3
# 60644                       1
#
# [60645 rows x 26 columns]

# %%
df = df.sort_values("Keyword_Priority_Value", ascending = False)
df
# Out:
#        Unnamed: 0  Unnamed: 0.1  index           Keyword  \
# 0              14            21     21       hurdle rate
# 54795      708002       1208887     24       hurdle rate
# 41634      571407        998244     88       hurdle rate
# 41613      571237        997954     23       hurdle rate
# 41600      571016        997591     64       hurdle rate
# ...           ...           ...    ...               ...
# 43374      589355       1026534     73              WACC
# 43373      589354       1026533     72              WACC
# 43372      589345       1026517     56  return on assets
# 43371      589333       1026501     40               OCC
# 37067      520198        902716    159  return on assets
#
#                                                     Para    Report PPV TOC  \
# 0      THE CALLER: Okay. In terms of the margins, the...   8009953   N   N
# 54795  David Kerstens - Jefferies LLC, Research Divis...  67840685   N   Y
# 41634  Unidentified Analyst And a question for Jayne,...  62619855   N   Y
# 41613  George D. Schindler - CGI Group Inc. - CEO, Pr...  62557965   N   Y
# 41600  James F. Risoleo - Host Hotels & Resorts, Inc....  62530912   N   Y
# ...                                                  ...       ...  ..  ..
# 43374  As said earlier, when we're looking at the fin...  62970936   N   Y
# 43373   prevent significant bill volatility. So what ...  62970936   N   Y
# 43372  The momentum we established last year has cont...  62973237   N   Y
# 43371  Timothy J. Sloan - Wells Fargo & Company - CEO...  62973047   N   Y
# 37067  David Blackman - Select Income REIT - Presiden...  28404011   N   Y
#
#                                                    Title  \
# 0      VARCO INTERNATIONAL INCORPORATED (VRC) - Q2 20...
# 54795                                            DSV A/S
# 41634                                QANTAS AIRWAYS LTD.
# 41613                                     CGI GROUP INC.
# 41600                        HOST HOTELS AND RESORTS INC
# ...                                                  ...
# 43374                                   SEVERN TRENT PLC
# 43373                                   SEVERN TRENT PLC
# 43372                                    CITIGROUP, INC.
# 43371                                  WELLS FARGO & CO.
# 37067                                 SELECT INCOME REIT
#
#                                                 Subtitle  ... Collection  \
# 0                                                         ...        INV
# 54795  DSV.CO - Event Transcript of DSV A/S conferenc...  ...        INV
# 41634  QAN.AX - Event Transcript of Qantas Airways Lt...  ...        INV
# 41613  GIBa.TO - Event Transcript of CGI Group Inc co...  ...        INV
# 41600  HST.N - Event Transcript of Host Hotels & Reso...  ...        INV
# ...                                                  ...  ...        ...
# 43374  SVT.L - Event Transcript of Severn Trent PLC c...  ...        INV
# 43373  SVT.L - Event Transcript of Severn Trent PLC c...  ...        INV
# 43372  C.N - Event Transcript of Citigroup Inc confer...  ...        INV
# 43371  WFC.N - Event Transcript of Wells Fargo & Co c...  ...        INV
# 37067  SIR.OQ^A19 - Event Transcript of Select Income...  ...        INV
#
#                                                     Call  \
# 0       \n \n\nTHE OPERATOR:\nGood morning and welcom...
# 54795   \n CORPORATE PARTICIPANTS\nJens Bjørn Anderse...
# 41634   \n CORPORATE PARTICIPANTS\nAlan Joseph Joyce ...
# 41613   \n CORPORATE PARTICIPANTS\nFrançois Boulanger...
# 41600   \n CORPORATE PARTICIPANTS\nGee Lingberg Host ...
# ...                                                  ...
# 43374   \n CORPORATE PARTICIPANTS\nAnthony J. Ballanc...
# 43373   \n CORPORATE PARTICIPANTS\nAnthony J. Ballanc...
# 43372   \n CORPORATE PARTICIPANTS\nJohn C. Gerspach C...
# 43371   \n CORPORATE PARTICIPANTS\nJames H. Rowe Well...
# 37067   \n CORPORATE PARTICIPANTS\nTim Bonang Select ...
#
#                            File HasNumber Correct NumberOfOccurences  \
# 0       20020726-20020729_4.csv       1.0    True                  1
# 54795   20190818-20190821_5.csv       1.0    True                  1
# 41634   20170504-20170507_1.csv       1.0    True                  1
# 41613   20170430-20170503_3.csv       1.0    True                  1
# 41600   20170426-20170429_5.csv       1.0    True                  1
# ...                         ...       ...     ...                ...
# 43374   20170711-20170714_1.csv       1.0    True                  1
# 43373   20170711-20170714_1.csv       1.0    True                  1
# 43372   20170711-20170714_1.csv       1.0    True                  1
# 43371   20170711-20170714_1.csv       1.0    True                  1
# 37067  20160215-20160218_12.csv       1.0    True                  1
#
#                         List_Keywords  Year Highest_Priority_Keyword  \
# 0                       [hurdle rate]  2002              hurdle rate
# 54795                   [hurdle rate]  2019              hurdle rate
# 41634                   [hurdle rate]  2017              hurdle rate
# 41613                   [hurdle rate]  2017              hurdle rate
# 41600  [cost of capital, hurdle rate]  2017              hurdle rate
# ...                               ...   ...                      ...
# 43374                          [WACC]  2017                     WACC
# 43373                          [WACC]  2017                     WACC
# 43372              [return on assets]  2017         return on assets
# 43371                           [OCC]  2017                      OCC
# 37067              [return on assets]  2016         return on assets
#
#        Keyword_Priority_Value
# 0                           5
# 54795                       5
# 41634                       5
# 41613                       5
# 41600                       5
# ...                       ...
# 43374                       0
# 43373                       0
# 43372                       0
# 43371                       0
# 37067                       0
#
# [60645 rows x 26 columns]

# %% [markdown]
# ### New Sorting Rule

# %%
df = pd.read_csv("Amended_Correct_No_IR.csv")
df["DateObject"] = df["Date"].apply(pd.to_datetime)
df["Year"] = df["DateObject"].apply(lambda x: x.year)
df
# Out:
#        Unnamed: 0  Unnamed: 0.1  index                     Keyword  \
# 0              14            21     21                 hurdle rate
# 1              24            36     36               discount rate
# 2              33            46     46            return on assets
# 3              40            57     57  return on invested capital
# 4              70            89     89            return on assets
# ...           ...           ...    ...                         ...
# 60640      784390       1330247    150             cost of capital
# 60641      784391       1330250    153                        ROIC
# 60642      784396       1330255    158                         OCC
# 60643      784397       1330256    159                        ROIC
# 60644      784399       1330258    161  return on invested capital
#
#                                                     Para    Report PPV TOC  \
# 0      THE CALLER: Okay. In terms of the margins, the...   8009953   N   N
# 1      MR. ANTHONY RUGGIERO: Return assumptions at th...   8009887   N   N
# 2       additional products that have entered Phase I...   8009956   N   N
# 3       11.54 cents per square foot, while capital on...   8009957   N   N
# 4       reserves in the Life Company and OFC Capital....   8009969   N   N
# ...                                                  ...       ...  ..  ..
# 60640  Shazad G. Dada - United Bank Limited - Preside...  71557135   N   Y
# 60641  So to close out this section, 2 days ago, in o...  71557147   N   Y
# 60642   Ashish Masih - Encore Capital Group, Inc. - P...  71557147   N   Y
# 60643  So yes, absolutely. We have also looked at acq...  71568653   N   Y
# 60644  Daniel J. Shook - IMI plc - Finance Director &...  71568653   N   Y
#
#                                                    Title  \
# 0      VARCO INTERNATIONAL INCORPORATED (VRC) - Q2 20...
# 1      OLIN CORPORATION (OLN) - Q2 2002 FINANCIAL REL...
# 2      SEROLOGICALS CORP. (SERO) - Q2 2002 FINANCIAL ...
# 3      BRANDYWINE REALTY TRUST (BDN) - Q2 2002 EARNIN...
# 4      ALFA CORPORATION (ALFA) - Q2 2002 FINANCIAL RE...
# ...                                                  ...
# 60640                                UNITED BANK LIMITED
# 60641                           ENCORE CAPITAL GROUP INC
# 60642                           ENCORE CAPITAL GROUP INC
# 60643                                            IMI PLC
# 60644                                            IMI PLC
#
#                                                 Subtitle  ... Language  \
# 0                                                         ...  English
# 1                                                         ...  English
# 2                                                         ...  English
# 3                                                         ...  English
# 4                                                         ...  English
# ...                                                  ...  ...      ...
# 60640  UBL.PSX - Event Transcript of United Bank Ltd ...  ...  English
# 60641  ECPG.OQ - Event Transcript of Encore Capital G...  ...  English
# 60642  ECPG.OQ - Event Transcript of Encore Capital G...  ...  English
# 60643  IMI.L - Event Transcript of IMI PLC conference...  ...  English
# 60644  IMI.L - Event Transcript of IMI PLC conference...  ...  English
#
#        Collection                                               Call  \
# 0             INV   \n \n\nTHE OPERATOR:\nGood morning and welcom...
# 1             INV   \n \n\nTHE OPERATOR:\nWelcome to the Olin Cor...
# 2             INV   \n \n\nTHE OPERATOR:\nGood day everyone and w...
# 3             INV   \n \n\nTHE OPERATOR:\nGood day ladies and gen...
# 4             INV   \n \n\nTHE OPERATOR:\nGood morning and welcom...
# ...           ...                                                ...
# 60640         INV   \n CORPORATE PARTICIPANTS\nAameer Mustaaly Ka...
# 60641         INV   \n CORPORATE PARTICIPANTS\nAshish Masih Encor...
# 60642         INV   \n CORPORATE PARTICIPANTS\nAshish Masih Encor...
# 60643         INV   \n CORPORATE PARTICIPANTS\nDaniel J. Shook IM...
# 60644         INV   \n CORPORATE PARTICIPANTS\nDaniel J. Shook IM...
#
#                           File HasNumber Correct NumberOfOccurences  \
# 0      20020726-20020729_4.csv       1.0    True                  1
# 1      20020726-20020729_4.csv       1.0    True                  1
# 2      20020726-20020729_4.csv       1.0    True                  1
# 3      20020726-20020729_4.csv       1.0    True                  2
# 4      20020726-20020729_4.csv       1.0    True                  1
# ...                        ...       ...     ...                ...
# 60640  20210225-20210301_9.csv       1.0    True                  1
# 60641  20210225-20210301_9.csv       1.0    True                  1
# 60642  20210225-20210301_9.csv       1.0    True                  2
# 60643  20210225-20210301_9.csv       1.0    True                  1
# 60644  20210225-20210301_9.csv       1.0    True                  1
#
#                                 List_Keywords DateObject  Year
# 0                             ['hurdle rate'] 2002-07-26  2002
# 1                           ['discount rate'] 2002-07-26  2002
# 2                        ['return on assets'] 2002-07-26  2002
# 3              ['return on invested capital'] 2002-07-26  2002
# 4                        ['return on assets'] 2002-07-26  2002
# ...                                       ...        ...   ...
# 60640                     ['cost of capital'] 2021-02-26  2021
# 60641  ['ROIC', 'return on invested capital'] 2021-02-26  2021
# 60642                                 ['OCC'] 2021-02-26  2021
# 60643             ['cost of capital', 'ROIC'] 2021-02-26  2021
# 60644          ['return on invested capital'] 2021-02-26  2021
#
# [60645 rows x 25 columns]

# %%
def contains_percent(t):
    text = t.lower()
    to_keep = ["%", "per cent", "percent", "percentage"]
    for i in to_keep:
        if i in text:
            return True
    return False

# %%
contains_percent("Hi, this is me.")
# Out:
# False

# %%
contains_percent("Hi, this % is me.")
# Out:
# True

# %%
contains_percent("Hello, I cannot say this. That's ridiculous")
# Out:
# False

# %%
contains_percent("Hello, I cannot say this. That's 100 Per Cent ridiculous")
# Out:
# True

# %%
df["Has%"] = df["Para"].apply(contains_percent)
df = df[df["Has%"] == True]
df
# Out:
#        Unnamed: 0  Unnamed: 0.1  index                     Keyword  \
# 0              14            21     21                 hurdle rate
# 1              24            36     36               discount rate
# 2              33            46     46            return on assets
# 3              40            57     57  return on invested capital
# 4              70            89     89            return on assets
# ...           ...           ...    ...                         ...
# 60629      784133       1329855    131  return on invested capital
# 60631      784153       1329886    162                         IRR
# 60636      784246       1330036     18             cost of capital
# 60637      784255       1330053     35                cost of debt
# 60638      784293       1330115     18                cost of debt
#
#                                                     Para    Report PPV TOC  \
# 0      THE CALLER: Okay. In terms of the margins, the...   8009953   N   N
# 1      MR. ANTHONY RUGGIERO: Return assumptions at th...   8009887   N   N
# 2       additional products that have entered Phase I...   8009956   N   N
# 3       11.54 cents per square foot, while capital on...   8009957   N   N
# 4       reserves in the Life Company and OFC Capital....   8009969   N   N
# ...                                                  ...       ...  ..  ..
# 60629  GF Machining Solutions targets an ROS of 8% to...  71588215   N   Y
# 60631  Currently, we know that there is a way to reco...  71577575   N   Y
# 60636  Looking now at our balance sheet and capital s...  71577617   N   Y
# 60637   Our available liquidity of $1.75 billion equa...  71577616   N   Y
# 60638                     i. Looks forward to bringin...  71557153   N   Y
#
#                                                    Title  \
# 0      VARCO INTERNATIONAL INCORPORATED (VRC) - Q2 20...
# 1      OLIN CORPORATION (OLN) - Q2 2002 FINANCIAL REL...
# 2      SEROLOGICALS CORP. (SERO) - Q2 2002 FINANCIAL ...
# 3      BRANDYWINE REALTY TRUST (BDN) - Q2 2002 EARNIN...
# 4      ALFA CORPORATION (ALFA) - Q2 2002 FINANCIAL RE...
# ...                                                  ...
# 60629                                   GEORG FISCHER AG
# 60631                                      AK ALROSA PAO
# 60636                PREFERRED APARTMENT COMMUNITIES INC
# 60637                              FS INVESTMENT CORP II
# 60638                                 HOWARD HUGHES CORP
#
#                                                 Subtitle  ... Collection  \
# 0                                                         ...        INV
# 1                                                         ...        INV
# 2                                                         ...        INV
# 3                                                         ...        INV
# 4                                                         ...        INV
# ...                                                  ...  ...        ...
# 60629  FIN.S - Event Transcript of Georg Fischer AG c...  ...        INV
# 60631  ALRS.MM - Event Transcript of AK Alrosa PAO co...  ...        INV
# 60636  APTS.N - Event Transcript of Preferred Apartme...  ...        INV
# 60637  FSKR.N - Event Transcript of FS KKR Capital Co...  ...        INV
# 60638  HHC.N - Event Brief of Howard Hughes Corp conf...  ...        INV
#
#                                                     Call  \
# 0       \n \n\nTHE OPERATOR:\nGood morning and welcom...
# 1       \n \n\nTHE OPERATOR:\nWelcome to the Olin Cor...
# 2       \n \n\nTHE OPERATOR:\nGood day everyone and w...
# 3       \n \n\nTHE OPERATOR:\nGood day ladies and gen...
# 4       \n \n\nTHE OPERATOR:\nGood morning and welcom...
# ...                                                  ...
# 60629   \n CORPORATE PARTICIPANTS\nAndreas Müller Geo...
# 60631   \n CORPORATE PARTICIPANTS\nAlexey Nikolaevich...
# 60636   \n CORPORATE PARTICIPANTS\nJoel T. Murphy Pre...
# 60637   \n CORPORATE PARTICIPANTS\nBrian Gerson FS KK...
# 60638   \n \nCORPORATE PARTICIPANTS\nDavid Michael St...
#
#                            File HasNumber Correct NumberOfOccurences  \
# 0       20020726-20020729_4.csv       1.0    True                  1
# 1       20020726-20020729_4.csv       1.0    True                  1
# 2       20020726-20020729_4.csv       1.0    True                  1
# 3       20020726-20020729_4.csv       1.0    True                  2
# 4       20020726-20020729_4.csv       1.0    True                  1
# ...                         ...       ...     ...                ...
# 60629  20210302-20210306_13.csv       1.0    True                  1
# 60631  20210302-20210306_13.csv       1.0    True                  1
# 60636  20210302-20210306_14.csv       1.0    True                  1
# 60637  20210302-20210306_14.csv       1.0    True                  1
# 60638   20210225-20210301_9.csv       1.0    True                  1
#
#                         List_Keywords DateObject  Year  Has%
# 0                     ['hurdle rate'] 2002-07-26  2002  True
# 1                   ['discount rate'] 2002-07-26  2002  True
# 2                ['return on assets'] 2002-07-26  2002  True
# 3      ['return on invested capital'] 2002-07-26  2002  True
# 4                ['return on assets'] 2002-07-26  2002  True
# ...                               ...        ...   ...   ...
# 60629  ['return on invested capital'] 2021-03-03  2021  True
# 60631                         ['IRR'] 2021-03-02  2021  True
# 60636             ['cost of capital'] 2021-03-02  2021  True
# 60637                ['cost of debt'] 2021-03-02  2021  True
# 60638                ['cost of debt'] 2021-02-26  2021  True
#
# [30818 rows x 26 columns]

# %%
keywords = pd.read_csv("keyterms.txt", sep = "\t", header = None)
d = defaultdict(int)
d["hurdle rate"] = 5
d["cost of equity"] = 4
d["cost of capital"] = 3
d["IRR"] = 2
d["internal rate of return"] = 2
d["ROIC"] = 1
d["return on invested capital"] = 1
keywords["priority"] = keywords[0].apply(lambda x: d[x])
keywords = keywords[keywords[0] != "interest rate"]
keywords["lower"] = keywords[0].str.lower()
priority_dict = dict(keywords.set_index(0)["priority"])

def choose_according_to_priority(l, keywords_priority_dict):
    t = []
    if len(l) == 1:
        main_keyword = l[0]
    else:
        for k in l:
            t.append(keywords_priority_dict[k])
        highest_priority_index = pd.Series(t).idxmax()
        main_keyword = l[highest_priority_index]
    return main_keyword

df["List_Keywords"] = df["List_Keywords"].apply(literal_eval)
df["Highest_Priority_Keyword"] = df["List_Keywords"].apply(lambda x: choose_according_to_priority(x, priority_dict))
df["Keyword_Priority_Value"] = df["Highest_Priority_Keyword"].apply(lambda x: priority_dict[x])
df = df.sort_values("Keyword_Priority_Value", ascending = False)
df["Keyword_Older"] = df["Keyword"]
df["Keyword"] = df["Highest_Priority_Keyword"]
df
# Out:
# <ipython-input-19-4dc6e1819bd0>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["List_Keywords"] = df["List_Keywords"].apply(literal_eval)
# <ipython-input-19-4dc6e1819bd0>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Highest_Priority_Keyword"] = df["List_Keywords"].apply(lambda x: choose_according_to_priority(x, priority_dict))
# <ipython-input-19-4dc6e1819bd0>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Keyword_Priority_Value"] = df["Highest_Priority_Keyword"].apply(lambda x: priority_dict[x])
#        Unnamed: 0  Unnamed: 0.1  index           Keyword  \
# 0              14            21     21       hurdle rate
# 45183      607846       1054607      4       hurdle rate
# 6249        96678        115087     83       hurdle rate
# 44839      604444       1049464     49       hurdle rate
# 44843      604510       1049558     71       hurdle rate
# ...           ...           ...    ...               ...
# 4390        67826         81043     60     discount rate
# 31990      465329        794465    147  return on assets
# 31996      465539        794861    114               OCC
# 31999      465616        795003     72      cost of debt
# 60638      784293       1330115     18      cost of debt
#
#                                                     Para    Report PPV TOC  \
# 0      THE CALLER: Okay. In terms of the margins, the...   8009953   N   N
# 45183   accounted in the R&D, okay? Because R&D is re...  63852948   N   Y
# 6249   Unknown Speaker* I would say -- Hal will proba...  10295829   N   Y
# 44839  Daniel B. Wolfe - 180 Degree Capital Corp. - P...  63688660   N   Y
# 44843  Troy Raymond MacLean - BMO Capital Markets Equ...  63736017   N   Y
# ...                                                  ...       ...  ..  ..
# 4390   separately on the income statement. And merger...   8907799   N   N
# 31990  Our core deposit franchise remains strong. Tot...  24370690   N   Y
# 31996  Really that was the sole improvement for the q...  24785663   N   Y
# 31999   So, as we talked about, the average kind of c...  24840526   N   Y
# 60638                     i. Looks forward to bringin...  71557153   N   Y
#
#                                                    Title  \
# 0      VARCO INTERNATIONAL INCORPORATED (VRC) - Q2 20...
# 45183                                         SOGEFI SPA
# 6249                                    TRANSCANADA CORP
# 44839                            180 DEGREE CAPITAL CORP
# 44843                      SUMMIT INDUSTRIAL INCOME REIT
# ...                                                  ...
# 4390   GENERAL MILLS INC. (GIS) - Q1 2004 GENERAL MIL...
# 31990  CACB.O^E17 - EVENT TRANSCRIPT OF CASCADE BANCO...
# 31996                               WASTE MANAGEMENT INC
# 31999                          NEWCASTLE INVESTMENT CORP
# 60638                                 HOWARD HUGHES CORP
#
#                                                 Subtitle  ... HasNumber  \
# 0                                                         ...       1.0
# 45183  SGFI.MI - Event Transcript of Sogefi SpA confe...  ...       1.0
# 6249                                                      ...       1.0
# 44839  TURN.OQ - Event Transcript of 180 Degree Capit...  ...       1.0
# 44843  SMU_u.TO - Event Transcript of Summit Industri...  ...       1.0
# ...                                                  ...  ...       ...
# 4390                                                      ...       1.0
# 31990  CACB.O^E17 - Event Transcript of Cascade Banco...  ...       1.0
# 31996  WM.N - Event Transcript of Waste Management In...  ...       1.0
# 31999  NCT.N - Event Transcript of Newcastle Investme...  ...       1.0
# 60638  HHC.N - Event Brief of Howard Hughes Corp conf...  ...       1.0
#
#        Correct NumberOfOccurences                   List_Keywords DateObject  \
# 0         True                  1                   [hurdle rate] 2002-07-26
# 45183     True                  1  [expected return, hurdle rate] 2017-11-28
# 6249      True                  1                   [hurdle rate] 2005-04-29
# 44839     True                  1                   [hurdle rate] 2017-11-02
# 44843     True                  1                   [hurdle rate] 2017-11-08
# ...        ...                ...                             ...        ...
# 4390      True                  1                 [discount rate] 2003-09-16
# 31990     True                  1              [return on assets] 2014-08-14
# 31996     True                  1                           [OCC] 2014-10-29
# 31999     True                  2                  [cost of debt] 2014-11-04
# 60638     True                  1                  [cost of debt] 2021-02-26
#
#        Year  Has% Highest_Priority_Keyword Keyword_Priority_Value  \
# 0      2002  True              hurdle rate                      5
# 45183  2017  True              hurdle rate                      5
# 6249   2005  True              hurdle rate                      5
# 44839  2017  True              hurdle rate                      5
# 44843  2017  True              hurdle rate                      5
# ...     ...   ...                      ...                    ...
# 4390   2003  True            discount rate                      0
# 31990  2014  True         return on assets                      0
# 31996  2014  True                      OCC                      0
# 31999  2014  True             cost of debt                      0
# 60638  2021  True             cost of debt                      0
#
#           Keyword_Older
# 0           hurdle rate
# 45183   expected return
# 6249        hurdle rate
# 44839       hurdle rate
# 44843       hurdle rate
# ...                 ...
# 4390      discount rate
# 31990  return on assets
# 31996               OCC
# 31999      cost of debt
# 60638      cost of debt
#
# [30818 rows x 29 columns]

# %%
important_1 = ["hurdle rate", "cost of equity", "cost of capital"]
c1 = df["Year"] >= 2005
c2 = df["Year"] <= 2010
c3 = df["Keyword"].isin(important_1)
df_1 = df[(c1) & (c2) & (c3)]
df_1 = df_1.sort_values(["Highest_Priority_Keyword", "Title", "DateObject"], ascending = [False, True, True])
df_1
# Out:
#        Unnamed: 0  Unnamed: 0.1  index          Keyword  \
# 16978      282142        442721      5      hurdle rate
# 5351        82902         97818     54      hurdle rate
# 5352        82903         97819     55      hurdle rate
# 9277       148125        200226     17      hurdle rate
# 9997       159240        219027     48      hurdle rate
# ...           ...           ...    ...              ...
# 7256       114592        143754     41  cost of capital
# 5635        87479        103676     41  cost of capital
# 7268       114810        144109     24  cost of capital
# 10186      162412        224470     10  cost of capital
# 10524      168582        235160     16  cost of capital
#
#                                                     Para    Report PPV TOC  \
# 16978  We expect to reach chief a return on capital i...  16811609   N   Y
# 5351   Our first priority for our free cash flow is t...  10135055   N   Y
# 5352   Danielle Fox - Merrill Lynch - Analyst My next...  10135055   N   Y
# 9277   Jos Streppel - AEGON N.V. - CFO Yes. It's a bi...  12061675   N   Y
# 9997   Go to the next slide. We had sales growth in o...  12520697   N   Y
# ...                                                  ...       ...  ..  ..
# 7256   The acquisition is DCF positive, for example w...  10340309   N   Y
# 5635   Bill Zollars - Yellow Roadway Corporation - Ch...  10156908   N   Y
# 7268   Unknown Speaker* Well, just talking about the ...  10451158   N   Y
# 10186  We had the first positive holiday comp in the ...  12586669   N   Y
# 10524  in an increase in unrecognized revenues for th...  12869009   N   Y
#
#                                      Title  \
# 16978     ACE LTD - PRELIMINARY TRANSCRIPT
# 5351                ADVANCE AUTO PARTS INC
# 5352                ADVANCE AUTO PARTS INC
# 9277                              AEGON NV
# 9997           AEGON NV - FINAL TRANSCRIPT
# ...                                    ...
# 7256                       YELL GROUP LTD.
# 5635                   YELLOW ROADWAY CORP
# 7268                       YUM! BRANDS INC
# 10186  ZALE CORP. - PRELIMINARY TRANSCRIPT
# 10524  ZALE CORP. - PRELIMINARY TRANSCRIPT
#
#                                                 Subtitle  ... HasNumber  \
# 16978  ACE - Event Transcript of ACE Limited conferen...  ...       1.0
# 5351                                                      ...       1.0
# 5352                                                      ...       1.0
# 9277   AEG conference call Final transcript, 8-Mar-07...  ...       1.0
# 9997   AEG conference call Final transcript, 9-Aug-07...  ...       1.0
# ...                                                  ...  ...       ...
# 7256                                                      ...       1.0
# 5635   YELL conference call Final transcript, 28-Feb-...  ...       1.0
# 7268                                                      ...       1.0
# 10186  ZLC conference call Final transcript, 30-Aug-0...  ...       1.0
# 10524  ZLC conference call Final transcript, 20-Nov-0...  ...       1.0
#
#        Correct NumberOfOccurences      List_Keywords DateObject  Year  Has%  \
# 16978     True                  1      [hurdle rate] 2010-10-28  2010  True
# 5351      True                  1      [hurdle rate] 2005-02-17  2005  True
# 5352      True                  1      [hurdle rate] 2005-02-17  2005  True
# 9277      True                  1      [hurdle rate] 2007-03-08  2007  True
# 9997      True                  1      [hurdle rate] 2007-08-09  2007  True
# ...        ...                ...                ...        ...   ...   ...
# 7256      True                  1  [cost of capital] 2005-05-17  2005  True
# 5635      True                  1  [cost of capital] 2005-02-28  2005  True
# 7268      True                  1  [cost of capital] 2005-07-14  2005  True
# 10186     True                  1  [cost of capital] 2007-08-30  2007  True
# 10524     True                  1  [cost of capital] 2007-11-20  2007  True
#
#       Highest_Priority_Keyword Keyword_Priority_Value    Keyword_Older
# 16978              hurdle rate                      5      hurdle rate
# 5351               hurdle rate                      5      hurdle rate
# 5352               hurdle rate                      5      hurdle rate
# 9277               hurdle rate                      5      hurdle rate
# 9997               hurdle rate                      5      hurdle rate
# ...                        ...                    ...              ...
# 7256           cost of capital                      3  cost of capital
# 5635           cost of capital                      3  cost of capital
# 7268           cost of capital                      3  cost of capital
# 10186          cost of capital                      3  cost of capital
# 10524          cost of capital                      3  cost of capital
#
# [1506 rows x 29 columns]

# %%
important_2 = ["hurdle rate", "cost of equity", "cost of capital"]
c1 = df["Year"] >= 2020
c2 = df["Keyword"].isin(important_2)
df_2 = df[(c1) & (c2)]
df_2 = df_2.sort_values(["Highest_Priority_Keyword", "Title", "DateObject"], ascending = [False, True, True])
df_2
# Out:
#        Unnamed: 0  Unnamed: 0.1  index          Keyword  \
# 56907      734260       1249643     97      hurdle rate
# 55153      711903       1215017     18      hurdle rate
# 56923      734397       1249854     60      hurdle rate
# 57089      736807       1253778     45      hurdle rate
# 55647      717758       1223904     28      hurdle rate
# ...           ...           ...    ...              ...
# 58486      758335       1288366     47  cost of capital
# 58487      758337       1288369     50  cost of capital
# 59194      767777       1303500      4  cost of capital
# 58705      761642       1293686    138  cost of capital
# 56740      731346       1245108     14  cost of capital
#
#                                                     Para    Report PPV TOC  \
# 56907  Without the impairments, the return on capital...  70013364   N   Y
# 55153  Please turn to Slide 20 and 21. We continue to...  68958827   N   Y
# 56923  Please turn to Slide 20 and 21. We continue to...  69448951   N   Y
# 57089  We also did a comparison on the next slide wit...  69498983   N   Y
# 55647  Mohamed Al Hashemi - Abu Dhabi National Oil Co...  68872053   N   Y
# ...                                                  ...       ...  ..  ..
# 58486             7. Since qtr.-end, Co. has complete...  71207235   N   Y
# 58487               b. Factoring in the remaining sha...  71207235   N   Y
# 59194  So we've done deal volume in that $1.5 billion...  70895137   N   Y
# 58705  We mentioned earlier that our 2020 weighted av...  71454014   N   Y
# 56740     A. Overview:       1. Visibility and confid...  70099959   N   Y
#
#                                                    Title  \
# 56907  - EVENT TRANSCRIPT OF VATTENFALL AB CONFERENCE...
# 55153                            180 DEGREE CAPITAL CORP
# 56923                            180 DEGREE CAPITAL CORP
# 57089                                        AAREAL BANK
# 55647    ABU DHABI NATIONAL OIL CO FOR DISTRIBUTION PJSC
# ...                                                  ...
# 58486                                       WP CAREY INC
# 58487                                       WP CAREY INC
# 59194                                       WP CAREY INC
# 58705                                       WP CAREY INC
# 56740                                             XILINX
#
#                                                 Subtitle  ... HasNumber  \
# 56907  - Event Transcript of Vattenfall AB conference...  ...       1.0
# 55153  TURN.OQ - Event Transcript of 180 Degree Capit...  ...       1.0
# 56923  TURN.OQ - Event Transcript of 180 Degree Capit...  ...       1.0
# 57089  ARLG.DE - Event Transcript of Aareal Bank AG c...  ...       1.0
# 55647  ADNOCDIST.AD - Event Transcript of Abu Dhabi N...  ...       1.0
# ...                                                  ...  ...       ...
# 58486  WPC.N - Event Brief of WP Carey Inc conference...  ...       1.0
# 58487  WPC.N - Event Brief of WP Carey Inc conference...  ...       1.0
# 59194  WPC.N - Event Transcript of WP Carey Inc confe...  ...       1.0
# 58705  WPC.N - Event Transcript of WP Carey Inc confe...  ...       1.0
# 56740  XLNX.OQ - Event Brief of Xilinx Inc conference...  ...       1.0
#
#        Correct NumberOfOccurences      List_Keywords DateObject  Year  Has%  \
# 56907     True                  1      [hurdle rate] 2020-07-21  2020  True
# 55153     True                  1      [hurdle rate] 2020-02-25  2020  True
# 56923     True                  1      [hurdle rate] 2020-05-06  2020  True
# 57089     True                  1      [hurdle rate] 2020-05-12  2020  True
# 55647     True                  1      [hurdle rate] 2020-02-12  2020  True
# ...        ...                ...                ...        ...   ...   ...
# 58486     True                  2  [cost of capital] 2020-10-30  2020  True
# 58487     True                  2  [cost of capital] 2020-10-30  2020  True
# 59194     True                  1  [cost of capital] 2020-11-18  2020  True
# 58705     True                  1  [cost of capital] 2021-02-12  2021  True
# 56740     True                  1  [cost of capital] 2020-07-30  2020  True
#
#       Highest_Priority_Keyword Keyword_Priority_Value    Keyword_Older
# 56907              hurdle rate                      5      hurdle rate
# 55153              hurdle rate                      5      hurdle rate
# 56923              hurdle rate                      5      hurdle rate
# 57089              hurdle rate                      5      hurdle rate
# 55647              hurdle rate                      5      hurdle rate
# ...                        ...                    ...              ...
# 58486          cost of capital                      3  cost of capital
# 58487          cost of capital                      3  cost of capital
# 59194          cost of capital                      3  cost of capital
# 58705          cost of capital                      3  cost of capital
# 56740          cost of capital                      3  cost of capital
#
# [497 rows x 29 columns]

# %%
other_years = [2001, 2002, 2003, 2004, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]
important_3 = ["hurdle rate", "cost of equity", "cost of capital"]
c1 = df["Year"].isin(other_years)
c2 = df["Keyword"].isin(important_3)
df_3 = df[(c1) & (c2)]
df_3 = df_3.sort_values(["Highest_Priority_Keyword", "Title", "DateObject"], ascending = [False, True, True])
df_3
# Out:
#        Unnamed: 0  Unnamed: 0.1  index          Keyword  \
# 47685      633328       1093358     42      hurdle rate
# 42036      575890       1005510     61      hurdle rate
# 44839      604444       1049464     49      hurdle rate
# 52350      680995       1165675     67      hurdle rate
# 54918      709255       1210837     32      hurdle rate
# ...           ...           ...    ...              ...
# 23208      362848        594087     20  cost of capital
# 25555      389499        644554     69  cost of capital
# 26667      402177        668424     65  cost of capital
# 5421        83854         98932    110  cost of capital
# 36210      510689        884326      6  cost of capital
#
#                                                     Para    Report PPV TOC  \
# 47685  We see a return on capital employed at 7.1% to...  65407495   N   Y
# 42036   have a significant reduction in our costs for...  62794010   N   Y
# 44839  Daniel B. Wolfe - 180 Degree Capital Corp. - P...  63688660   N   Y
# 52350   While the current budget and the slight incre...  67829486   N   Y
# 54918  Please turn to Slides 25 and 26. As we discuss...  68306379   N   Y
# ...                                                  ...       ...  ..  ..
# 23208  Subsequently, we did issue a series F preferre...  20303022   N   Y
# 25555  CORPORATE PARTICIPANTS James Abbott Zions Banc...  21370213   N   Y
# 26667  CORPORATE PARTICIPANTS James Abbott Zions Banc...  21775942   N   Y
# 5421   The third quarter provides an excellent illust...   9956503   N   Y
# 36210  And then the other thing which is really for G...  27350959   N   Y
#
#                                                    Title  \
# 47685  - EVENT TRANSCRIPT OF VATTENFALL AB CONFERENCE...
# 42036                            180 DEGREE CAPITAL CORP
# 44839                            180 DEGREE CAPITAL CORP
# 52350                            180 DEGREE CAPITAL CORP
# 54918                            180 DEGREE CAPITAL CORP
# ...                                                  ...
# 23208                                      ZIONS BANCORP
# 25555                                      ZIONS BANCORP
# 26667                                      ZIONS BANCORP
# 5421                        ZURICH FINANCIAL SERVICES AG
# 36210                          ZURICH INSURANCE GROUP AG
#
#                                                 Subtitle  ... HasNumber  \
# 47685  - Event Transcript of Vattenfall AB conference...  ...       1.0
# 42036  TURN.OQ - Event Transcript of 180 Degree Capit...  ...       1.0
# 44839  TURN.OQ - Event Transcript of 180 Degree Capit...  ...       1.0
# 52350  TURN.OQ - Event Transcript of 180 Degree Capit...  ...       1.0
# 54918  TURN.OQ - Event Transcript of 180 Degree Capit...  ...       1.0
# ...                                                  ...  ...       ...
# 23208  ZION - Event Transcript of Zions Bancorporatio...  ...       1.0
# 25555  ZION.OQ - Event Brief of Zions Bancorporation ...  ...       1.0
# 26667  ZION.OQ - Event Brief of Zions Bancorporation ...  ...       1.0
# 5421   ZFSVY conference call Final transcript, 17-Nov...  ...       1.0
# 36210  ZURN.VX - Event Transcript of Zurich Insurance...  ...       1.0
#
#        Correct NumberOfOccurences                    List_Keywords DateObject  \
# 47685     True                  1                    [hurdle rate] 2018-07-20
# 42036     True                  1                    [hurdle rate] 2017-06-13
# 44839     True                  1                    [hurdle rate] 2017-11-02
# 52350     True                  1                    [hurdle rate] 2019-08-15
# 54918     True                  1                    [hurdle rate] 2019-11-08
# ...        ...                ...                              ...        ...
# 23208     True                  1                [cost of capital] 2012-05-30
# 25555     True                  1  [cost of capital, cost of debt] 2013-01-28
# 26667     True                  1                [cost of capital] 2013-04-22
# 5421      True                  1                [cost of capital] 2004-11-17
# 36210     True                  2                [cost of capital] 2015-11-05
#
#        Year  Has% Highest_Priority_Keyword Keyword_Priority_Value  \
# 47685  2018  True              hurdle rate                      5
# 42036  2017  True              hurdle rate                      5
# 44839  2017  True              hurdle rate                      5
# 52350  2019  True              hurdle rate                      5
# 54918  2019  True              hurdle rate                      5
# ...     ...   ...                      ...                    ...
# 23208  2012  True          cost of capital                      3
# 25555  2013  True          cost of capital                      3
# 26667  2013  True          cost of capital                      3
# 5421   2004  True          cost of capital                      3
# 36210  2015  True          cost of capital                      3
#
#          Keyword_Older
# 47685      hurdle rate
# 42036      hurdle rate
# 44839      hurdle rate
# 52350      hurdle rate
# 54918      hurdle rate
# ...                ...
# 23208  cost of capital
# 25555  cost of capital
# 26667  cost of capital
# 5421   cost of capital
# 36210  cost of capital
#
# [5116 rows x 29 columns]

# %%
important_4 = ["IRR", "internal rate of return", "ROIC", "return on invested capital"]
c1 = df["Year"] >= 2005
c2 = df["Year"] <= 2010
c3 = df["Keyword"].isin(important_4)
df_4 = df[(c1) & (c2) & (c3)]
df_4 = df_4.sort_values(["Highest_Priority_Keyword", "Title", "DateObject"], ascending = [False, True, True])
df_4
# Out:
#        Unnamed: 0  Unnamed: 0.1  index                     Keyword  \
# 7143       112266        139803     42  return on invested capital
# 6044        93351        110919    111  return on invested capital
# 10969      176403        248285     17  return on invested capital
# 10971      176411        248296     28  return on invested capital
# 6250        96798        115288     21  return on invested capital
# ...           ...           ...    ...                         ...
# 17582      292625        462761     14                         IRR
# 6736       104985        127615     61                         IRR
# 6737       104986        127616     62                         IRR
# 6738       104988        127621     67                         IRR
# 6740       104991        127624     70                         IRR
#
#                                                     Para    Report PPV TOC  \
# 7143   David Strine - Bear Stearns - Analyst Okay, th...  29924124   N   Y
# 6044   We will not pay for synergistic opportunities,...  61088113   N   Y
# 10969  So another question is, is it working? You see...  12970710   N   Y
# 10971  One of the things we've really been driven to ...  12970710   N   Y
# 6250   Local currency sales in electro and communicat...  10059079   N   Y
# ...                                                  ...       ...  ..  ..
# 17582  Thank you, Harlan, and good morning to everyon...  16506246   N   Y
# 6736   Manuel Ramirez Okay, so 40 basis points on $1 ...  10434553   N   Y
# 6737    Doyle Arnold I don't know that we ever talked...  10434553   N   Y
# 6738   Harris Simmons I think the return on equity wh...  10434553   N   Y
# 6740   Frank McMahon Doyle, it's Frank McMahon. Fitch...  10434553   N   Y
#
#                                                    Title  \
# 7143   - EVENT BRIEF OF US AIRWAYS GROUP INC CONFEREN...
# 6044   - EVENT TRANSCRIPT OF JONES GROUP INC CONFEREN...
# 10969                     3M CO - PRELIMINARY TRANSCRIPT
# 10971                     3M CO - PRELIMINARY TRANSCRIPT
# 6250                                             3M CORP
# ...                                                  ...
# 17582  YANKEE CANDLE COMPANY, INC. - PRELIMINARY TRAN...
# 6736                                       ZIONS BANCORP
# 6737                                       ZIONS BANCORP
# 6738                                       ZIONS BANCORP
# 6740                                       ZIONS BANCORP
#
#                                                 Subtitle  ... HasNumber  \
# 7143   - Event Brief of US Airways Group Inc conferen...  ...       1.0
# 6044   - Event Transcript of Jones Group Inc conferen...  ...       1.0
# 10969  MMM conference call Final transcript, 12-Dec-0...  ...       1.0
# 10971  MMM conference call Final transcript, 12-Dec-0...  ...       1.0
# 6250                                                      ...       1.0
# ...                                                  ...  ...       ...
# 17582  **YCC - Event Transcript of Yankee Candle conf...  ...       1.0
# 6736                                                      ...       1.0
# 6737                                                      ...       1.0
# 6738                                                      ...       1.0
# 6740                                                      ...       1.0
#
#        Correct NumberOfOccurences                 List_Keywords DateObject  \
# 7143      True                  1  [return on invested capital] 2005-05-20
# 6044      True                  1  [return on invested capital] 2005-03-08
# 10969     True                  1  [return on invested capital] 2007-12-12
# 10971     True                  1  [return on invested capital] 2007-12-12
# 6250      True                  1  [return on invested capital] 2005-01-18
# ...        ...                ...                           ...        ...
# 17582     True                  1                         [IRR] 2010-08-12
# 6736      True                  1                         [IRR] 2005-07-06
# 6737      True                  1                         [IRR] 2005-07-06
# 6738      True                  2                         [IRR] 2005-07-06
# 6740      True                  1                         [IRR] 2005-07-06
#
#        Year  Has%    Highest_Priority_Keyword Keyword_Priority_Value  \
# 7143   2005  True  return on invested capital                      1
# 6044   2005  True  return on invested capital                      1
# 10969  2007  True  return on invested capital                      1
# 10971  2007  True  return on invested capital                      1
# 6250   2005  True  return on invested capital                      1
# ...     ...   ...                         ...                    ...
# 17582  2010  True                         IRR                      2
# 6736   2005  True                         IRR                      2
# 6737   2005  True                         IRR                      2
# 6738   2005  True                         IRR                      2
# 6740   2005  True                         IRR                      2
#
#                     Keyword_Older
# 7143   return on invested capital
# 6044   return on invested capital
# 10969  return on invested capital
# 10971  return on invested capital
# 6250   return on invested capital
# ...                           ...
# 17582                         IRR
# 6736                          IRR
# 6737                          IRR
# 6738                          IRR
# 6740                          IRR
#
# [2362 rows x 29 columns]

# %%
important_5 = ["IRR", "internal rate of return", "ROIC", "return on invested capital"]
c1 = df["Year"] >= 2020
c2 = df["Keyword"].isin(important_5)
df_5 = df[(c1) & (c2)]
df_5 = df_5.sort_values(["Highest_Priority_Keyword", "Title", "DateObject"], ascending = [False, True, True])
df_5
# Out:
#        Unnamed: 0  Unnamed: 0.1  index                     Keyword  \
# 56328      725938       1236536    128  return on invested capital
# 55657      717875       1224086     88  return on invested capital
# 55917      720797       1228595      9  return on invested capital
# 59693      773399       1312571    152  return on invested capital
# 59458      770953       1308647     38  return on invested capital
# ...           ...           ...    ...                         ...
# 55618      717383       1223338     65                         IRR
# 57310      741058       1260530     32                         IRR
# 60515      782908       1327842     15                         IRR
# 58135      753463       1280441     13                         IRR
# 58869      763774       1297053     58                         IRR
#
#                                                     Para    Report PPV TOC  \
# 56328  Please turn to Slide 15. As a result of our wo...  68743040   N   Y
# 55657  James D. DeVries - ADT Inc. - CEO, President &...  69020089   N   Y
# 55917  Now we think when we look at this, we will see...  68777050   N   Y
# 59693   non-GAAP EPS of greater than $7.50; and retur...  71046376   N   Y
# 59458   We delivered outstanding financial results in...  71430240   N   Y
# ...                                                  ...       ...  ..  ..
# 55618  Frank Joseph Schiraldi - Piper Sandler & Co., ...  68702124   N   Y
# 57310  Secondarily, the decrease from the first quart...  69377941   N   Y
# 60515  Dominic C. Canuso - WSFS Financial Corporation...  71643152   N   Y
# 58135              c. XRX devices add additional leve...  70681540   N   Y
# 58869   As we show in 2019, using a copper price of $...  71325013   N   Y
#
#                                  Title  \
# 56328                            3M CO
# 55657                          ADT INC
# 55917  ADVANCED ENERGY INDUSTRIES INC.
# 59693  ADVANCED ENERGY INDUSTRIES INC.
# 59458  ADVANCED ENERGY INDUSTRIES INC.
# ...                                ...
# 55618             WSFS FINANCIAL CORP.
# 57310             WSFS FINANCIAL CORP.
# 60515             WSFS FINANCIAL CORP.
# 58135                      XEROX CORP.
# 58869                  YAMANA GOLD INC
#
#                                                 Subtitle  ... HasNumber  \
# 56328  MMM.N - Event Transcript of 3M Co conference c...  ...       1.0
# 55657  ADT.N - Event Transcript of ADT Inc conference...  ...       1.0
# 55917  AEIS.OQ - Event Transcript of Advanced Energy ...  ...       1.0
# 59693  AEIS.OQ - Event Transcript of Advanced Energy ...  ...       1.0
# 59458  AEIS.OQ - Event Transcript of Advanced Energy ...  ...       1.0
# ...                                                  ...  ...       ...
# 55618  WSFS.OQ - Event Transcript of WSFS Financial C...  ...       1.0
# 57310  WSFS.OQ - Event Transcript of WSFS Financial C...  ...       1.0
# 60515  WSFS.OQ - Event Transcript of WSFS Financial C...  ...       1.0
# 58135  XRX.N - Event Brief of Xerox Holdings Corp con...  ...       1.0
# 58869  YRI.TO - Event Transcript of Yamana Gold Inc c...  ...       1.0
#
#        Correct NumberOfOccurences                 List_Keywords DateObject  \
# 56328     True                  1  [return on invested capital] 2020-01-28
# 55657     True                  1  [return on invested capital] 2020-03-05
# 55917     True                  1  [return on invested capital] 2020-01-15
# 59693     True                  1  [return on invested capital] 2020-12-14
# 59458     True                  1  [return on invested capital] 2021-02-10
# ...        ...                ...                           ...        ...
# 55618     True                  1                         [IRR] 2020-01-22
# 57310     True                  1                         [IRR] 2020-04-28
# 60515     True                  1                         [IRR] 2021-03-10
# 58135     True                  1                         [IRR] 2020-10-27
# 58869     True                  1          [IRR, discount rate] 2021-01-26
#
#        Year  Has%    Highest_Priority_Keyword Keyword_Priority_Value  \
# 56328  2020  True  return on invested capital                      1
# 55657  2020  True  return on invested capital                      1
# 55917  2020  True  return on invested capital                      1
# 59693  2020  True  return on invested capital                      1
# 59458  2021  True  return on invested capital                      1
# ...     ...   ...                         ...                    ...
# 55618  2020  True                         IRR                      2
# 57310  2020  True                         IRR                      2
# 60515  2021  True                         IRR                      2
# 58135  2020  True                         IRR                      2
# 58869  2021  True                         IRR                      2
#
#                     Keyword_Older
# 56328  return on invested capital
# 55657  return on invested capital
# 55917  return on invested capital
# 59693  return on invested capital
# 59458  return on invested capital
# ...                           ...
# 55618                         IRR
# 57310                         IRR
# 60515                         IRR
# 58135                         IRR
# 58869                         IRR
#
# [1078 rows x 29 columns]

# %%
other_years = [2001, 2002, 2003, 2004, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]
important_6 = ["IRR", "internal rate of return", "ROIC", "return on invested capital"]
c1 = df["Year"].isin(other_years)
c2 = df["Keyword"].isin(important_6)
df_6 = df[(c1) & (c2)]
df_6 = df_6.sort_values(["Highest_Priority_Keyword", "Title", "DateObject"], ascending = [False, True, True])
df_6
# Out:
#        Unnamed: 0  Unnamed: 0.1  index                     Keyword  \
# 36945      519234        900907     40  return on invested capital
# 508          8058         11366     53  return on invested capital
# 3999        61590         74259     84  return on invested capital
# 4004        61641         74315    140  return on invested capital
# 26966      406136        676206     69  return on invested capital
# ...           ...           ...    ...                         ...
# 43755      593547       1032839     65                         IRR
# 45863      614183       1064287     67                         IRR
# 47371      630175       1088557     19                         IRR
# 47033      626488       1082884     57                         IRR
# 48068      636935       1098995     65                         IRR
#
#                                                     Para    Report PPV TOC  \
# 36945  The US will also remain a key market, the US g...  29254167   N   Y
# 508    MR. JAMES MCCANN: Thank you, Joe and good morn...   8711117   N   N
# 3999   Bruce Claflin - 3Com - President and CEO When ...   8907944   N   N
# 4004   Bruce Claflin - 3Com - President and CEO When ...   8907957   N   N
# 26966  If you look at the filings we have done over t...  21625979   N   Y
# ...                                                  ...       ...  ..  ..
# 43755  Matt Steinfort - Zayo Group Holdings, Inc. - C...  63797510   N   Y
# 45863  John F. Waters - Zayo Group Holdings, Inc. - C...  64995491   N   Y
# 47371  Matt Steinfort - Zayo Group Holdings, Inc. - C...  65136170   N   Y
# 47033  Stock-based compensation was $26 million for t...  65620074   N   Y
# 48068   assume that you're still going to target the ...  65703154   N   Y
#
#                                                    Title  \
# 36945  - EVENT TRANSCRIPT OF CASH AMERICA INTERNATION...
# 508    1-800-FLOWERS.COM (FLWS) - Q4 2002 FINANCIAL R...
# 3999   3COM CORP. (COMS) - Q1 2004 3COM EARNINGS CONF...
# 4004   3COM CORP. (COMS) - Q1 2004 3COM EARNINGS CONF...
# 26966                                              3M CO
# ...                                                  ...
# 43755                            ZAYO GROUP HOLDINGS INC
# 45863                            ZAYO GROUP HOLDINGS INC
# 47371                            ZAYO GROUP HOLDINGS INC
# 47033                            ZAYO GROUP HOLDINGS INC
# 48068                            ZAYO GROUP HOLDINGS INC
#
#                                                 Subtitle  ... HasNumber  \
# 36945  - Event Transcript of Cash America Internation...  ...       1.0
# 508                                                       ...       1.0
# 3999                                                      ...       1.0
# 4004                                                      ...       1.0
# 26966  MMM.N - Event Transcript of 3M Co conference c...  ...       1.0
# ...                                                  ...  ...       ...
# 43755  ZAYO.N - Event Transcript of Zayo Group Holdin...  ...       1.0
# 45863  ZAYO.N - Event Transcript of Zayo Group Holdin...  ...       1.0
# 47371  ZAYO.N - Event Transcript of Zayo Group Holdin...  ...       1.0
# 47033  ZAYO.N - Event Transcript of Zayo Group Holdin...  ...       1.0
# 48068  ZAYO.N - Event Transcript of Zayo Group Holdin...  ...       1.0
#
#        Correct NumberOfOccurences                 List_Keywords DateObject  \
# 36945     True                  1  [return on invested capital] 2016-04-28
# 508       True                  1  [return on invested capital] 2002-08-07
# 3999      True                  1  [return on invested capital] 2003-09-18
# 4004      True                  1  [return on invested capital] 2003-09-18
# 26966     True                  1  [return on invested capital] 2013-03-21
# ...        ...                ...                           ...        ...
# 43755     True                  1                         [IRR] 2017-11-17
# 45863     True                  1                         [IRR] 2018-05-15
# 47371     True                  1                         [IRR] 2018-06-07
# 47033     True                  1                         [IRR] 2018-08-22
# 48068     True                  1                         [IRR] 2018-09-06
#
#        Year  Has%    Highest_Priority_Keyword Keyword_Priority_Value  \
# 36945  2016  True  return on invested capital                      1
# 508    2002  True  return on invested capital                      1
# 3999   2003  True  return on invested capital                      1
# 4004   2003  True  return on invested capital                      1
# 26966  2013  True  return on invested capital                      1
# ...     ...   ...                         ...                    ...
# 43755  2017  True                         IRR                      2
# 45863  2018  True                         IRR                      2
# 47371  2018  True                         IRR                      2
# 47033  2018  True                         IRR                      2
# 48068  2018  True                         IRR                      2
#
#                     Keyword_Older
# 36945  return on invested capital
# 508    return on invested capital
# 3999   return on invested capital
# 4004   return on invested capital
# 26966  return on invested capital
# ...                           ...
# 43755                         IRR
# 45863                         IRR
# 47371                         IRR
# 47033                         IRR
# 48068                         IRR
#
# [9594 rows x 29 columns]

# %%
df_7 = df[~(df.index.isin(df_1.index) | df.index.isin(df_2.index) | df.index.isin(df_3.index)
           |df.index.isin(df_4.index) | df.index.isin(df_5.index) | df.index.isin(df_6.index))]
df_7 = df_7.sort_values(["Highest_Priority_Keyword", "Title", "DateObject"], ascending = [False, True, True])
df_7
# Out:
#        Unnamed: 0  Unnamed: 0.1  index               Keyword  \
# 47035      626507       1082916     89  return on net assets
# 60547      783468       1328727     70  return on net assets
# 60546      783467       1328726     69  return on net assets
# 3877        59289         71842     55  return on net assets
# 194          3193          4455     44  return on net assets
# ...           ...           ...    ...                   ...
# 55278      713488       1217405     17                  CAPM
# 13351      220856        326949     31                  CAPM
# 52833      686253       1174174     81                  CAPM
# 2612        36585         47992    131                  CAPM
# 54986      709873       1211807     88                  CAPM
#
#                                                     Para    Report PPV TOC  \
# 47035  Joe Kuen Mok - AAC Technologies Holdings Inc. ...  65617523   N   Y
# 60547  Well, that concludes my prepared remarks. Give...  71596823   N   Y
# 60546  As you already heard this morning, return on n...  71596823   N   Y
# 3877   earnings per share of .58 cents per share. Abo...   8727355   N   N
# 194     MR. JOHN OWINGS: Thank you, Alex. Thank you f...   8009398   N   N
# ...                                                  ...       ...  ..  ..
# 55278              b. Expects to capitalize projects ...  68931059   N   Y
# 13351  Unidentified Hold on one minute. It's 13% at t...  14370045   N   Y
# 52833  João Caetano Carreira Faria Conceição - REN - ...  67257248   N   Y
# 2612   _____________________________________________ ...   8906619   N   N
# 54986  Next slide. So this is one -- and this is not ...  68386575   N   Y
#
#                                                    Title  \
# 47035                      AAC TECHNOLOGIES HOLDINGS INC
# 60547                                   AGCO CORPORATION
# 60546                                   AGCO CORPORATION
# 3877   AIR PRODUCT & CHEMICALS (APD) - Q2 2003 FINANC...
# 194    AIR PRODUCT & CHEMICALS (APD) - Q3 2002 FINANC...
# ...                                                  ...
# 55278                                  EVERSOURCE ENERGY
# 13351  NEW YORK TIMES COMPANY (THE) - PRELIMINARY TRA...
# 52833            REN REDES ENERGETICAS NACIONAIS SGPS SA
# 2612   SELECTIVE INSURANCE GROUP (SIGI) - Q2 2003 FIN...
# 54986                                          TALANX AG
#
#                                                 Subtitle  ... HasNumber  \
# 47035  2018.HK - Event Transcript of AAC Technologies...  ...       1.0
# 60547  AGCO.N - Event Transcript of AGCO Corp confere...  ...       1.0
# 60546  AGCO.N - Event Transcript of AGCO Corp confere...  ...       1.0
# 3877                                                      ...       1.0
# 194                                                       ...       1.0
# ...                                                  ...  ...       ...
# 55278  ES.N - Event Brief of Eversource Energy confer...  ...       1.0
# 13351  NYT conference call Final transcript, 28-Jan-0...  ...       1.0
# 52833  RENE.LS - Event Transcript of Ren Redes Energe...  ...       1.0
# 2612                                                      ...       1.0
# 54986  TLXGn.DE - Event Transcript of Talanx AG confe...  ...       1.0
#
#        Correct NumberOfOccurences           List_Keywords DateObject  Year  \
# 47035     True                  1  [return on net assets] 2018-08-22  2018
# 60547     True                  1  [return on net assets] 2021-03-03  2021
# 60546     True                  1  [return on net assets] 2021-03-03  2021
# 3877      True                  1  [return on net assets] 2003-04-24  2003
# 194       True                  1  [return on net assets] 2002-07-23  2002
# ...        ...                ...                     ...        ...   ...
# 55278     True                  1                  [CAPM] 2020-02-20  2020
# 13351     True                  1                  [CAPM] 2009-01-28  2009
# 52833     True                  2                  [CAPM] 2019-05-06  2019
# 2612      True                  1                  [CAPM] 2003-08-06  2003
# 54986     True                  1                  [CAPM] 2019-11-20  2019
#
#        Has% Highest_Priority_Keyword Keyword_Priority_Value  \
# 47035  True     return on net assets                      0
# 60547  True     return on net assets                      0
# 60546  True     return on net assets                      0
# 3877   True     return on net assets                      0
# 194    True     return on net assets                      0
# ...     ...                      ...                    ...
# 55278  True                     CAPM                      0
# 13351  True                     CAPM                      0
# 52833  True                     CAPM                      0
# 2612   True                     CAPM                      0
# 54986  True                     CAPM                      0
#
#               Keyword_Older
# 47035  return on net assets
# 60547  return on net assets
# 60546  return on net assets
# 3877   return on net assets
# 194    return on net assets
# ...                     ...
# 55278                  CAPM
# 13351                  CAPM
# 52833                  CAPM
# 2612                   CAPM
# 54986                  CAPM
#
# [10665 rows x 29 columns]

# %%
l = [df_1, df_2, df_3, df_4, df_5, df_6, df_7]
temp = pd.concat(l)
temp
# Out:
#        Unnamed: 0  Unnamed: 0.1  index      Keyword  \
# 16978      282142        442721      5  hurdle rate
# 5351        82902         97818     54  hurdle rate
# 5352        82903         97819     55  hurdle rate
# 9277       148125        200226     17  hurdle rate
# 9997       159240        219027     48  hurdle rate
# ...           ...           ...    ...          ...
# 55278      713488       1217405     17         CAPM
# 13351      220856        326949     31         CAPM
# 52833      686253       1174174     81         CAPM
# 2612        36585         47992    131         CAPM
# 54986      709873       1211807     88         CAPM
#
#                                                     Para    Report PPV TOC  \
# 16978  We expect to reach chief a return on capital i...  16811609   N   Y
# 5351   Our first priority for our free cash flow is t...  10135055   N   Y
# 5352   Danielle Fox - Merrill Lynch - Analyst My next...  10135055   N   Y
# 9277   Jos Streppel - AEGON N.V. - CFO Yes. It's a bi...  12061675   N   Y
# 9997   Go to the next slide. We had sales growth in o...  12520697   N   Y
# ...                                                  ...       ...  ..  ..
# 55278              b. Expects to capitalize projects ...  68931059   N   Y
# 13351  Unidentified Hold on one minute. It's 13% at t...  14370045   N   Y
# 52833  João Caetano Carreira Faria Conceição - REN - ...  67257248   N   Y
# 2612   _____________________________________________ ...   8906619   N   N
# 54986  Next slide. So this is one -- and this is not ...  68386575   N   Y
#
#                                                    Title  \
# 16978                   ACE LTD - PRELIMINARY TRANSCRIPT
# 5351                              ADVANCE AUTO PARTS INC
# 5352                              ADVANCE AUTO PARTS INC
# 9277                                            AEGON NV
# 9997                         AEGON NV - FINAL TRANSCRIPT
# ...                                                  ...
# 55278                                  EVERSOURCE ENERGY
# 13351  NEW YORK TIMES COMPANY (THE) - PRELIMINARY TRA...
# 52833            REN REDES ENERGETICAS NACIONAIS SGPS SA
# 2612   SELECTIVE INSURANCE GROUP (SIGI) - Q2 2003 FIN...
# 54986                                          TALANX AG
#
#                                                 Subtitle  ... HasNumber  \
# 16978  ACE - Event Transcript of ACE Limited conferen...  ...       1.0
# 5351                                                      ...       1.0
# 5352                                                      ...       1.0
# 9277   AEG conference call Final transcript, 8-Mar-07...  ...       1.0
# 9997   AEG conference call Final transcript, 9-Aug-07...  ...       1.0
# ...                                                  ...  ...       ...
# 55278  ES.N - Event Brief of Eversource Energy confer...  ...       1.0
# 13351  NYT conference call Final transcript, 28-Jan-0...  ...       1.0
# 52833  RENE.LS - Event Transcript of Ren Redes Energe...  ...       1.0
# 2612                                                      ...       1.0
# 54986  TLXGn.DE - Event Transcript of Talanx AG confe...  ...       1.0
#
#        Correct NumberOfOccurences  List_Keywords DateObject  Year  Has%  \
# 16978     True                  1  [hurdle rate] 2010-10-28  2010  True
# 5351      True                  1  [hurdle rate] 2005-02-17  2005  True
# 5352      True                  1  [hurdle rate] 2005-02-17  2005  True
# 9277      True                  1  [hurdle rate] 2007-03-08  2007  True
# 9997      True                  1  [hurdle rate] 2007-08-09  2007  True
# ...        ...                ...            ...        ...   ...   ...
# 55278     True                  1         [CAPM] 2020-02-20  2020  True
# 13351     True                  1         [CAPM] 2009-01-28  2009  True
# 52833     True                  2         [CAPM] 2019-05-06  2019  True
# 2612      True                  1         [CAPM] 2003-08-06  2003  True
# 54986     True                  1         [CAPM] 2019-11-20  2019  True
#
#       Highest_Priority_Keyword Keyword_Priority_Value  Keyword_Older
# 16978              hurdle rate                      5    hurdle rate
# 5351               hurdle rate                      5    hurdle rate
# 5352               hurdle rate                      5    hurdle rate
# 9277               hurdle rate                      5    hurdle rate
# 9997               hurdle rate                      5    hurdle rate
# ...                        ...                    ...            ...
# 55278                     CAPM                      0           CAPM
# 13351                     CAPM                      0           CAPM
# 52833                     CAPM                      0           CAPM
# 2612                      CAPM                      0           CAPM
# 54986                     CAPM                      0           CAPM
#
# [30818 rows x 29 columns]

# %%
temp.to_csv("Filtered_Ordered_Amended_Correct_No_IR.csv", index = False)
