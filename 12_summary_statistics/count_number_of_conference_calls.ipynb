# %%
import pandas as pd
from pathlib import Path
import csv

# %%
xlsfolder = Path(r"C:\Users\jasonjia\Dropbox\Projects\conference_call\output\01_download_cc\01.1_xls_2")
outputfilepath = Path(r"C:\Users\jasonjia\Dropbox\Projects\conference_call\output\12_summary_statistics\report_id_01.1_xls_2.csv")

# %%
df_report_id_compiled = pd.DataFrame()

# For each xls file, read and get a list of the report IDs, then save it as a csv file
for xlsfile in xlsfolder.iterdir():
    if xlsfile.suffix == '.xls':
        print(xlsfile)
        df_report_id = pd.read_html(xlsfile)[0]['Report #']
        if df_report_id_compiled.shape[0] == 0:
            df_report_id_compiled = df_report_id
        else:
            df_report_id_compiled = df_report_id_compiled.append(df_report_id)
        print(df_report_id_compiled.shape)
# Out:
# C:\Users\jasonjia\Dropbox\Projects\conference_call\output\01_download_cc\01.1_xls_2\20201001-20201004_1.xls
# (47,)
# C:\Users\jasonjia\Dropbox\Projects\conference_call\output\01_download_cc\01.1_xls_2\20201005-20201008_1.xls
# (97,)
# C:\Users\jasonjia\Dropbox\Projects\conference_call\output\01_download_cc\01.1_xls_2\20201005-20201008_2.xls
# (147,)
# C:\Users\jasonjia\Dropbox\Projects\conference_call\output\01_download_cc\01.1_xls_2\20201005-20201008_3.xls
# (197,)
# C:\Users\jasonjia\Dropbox\Projects\conference_call\output\01_download_cc\01.1_xls_2\20201005-20201008_4.xls
# (198,)
# C:\Users\jasonjia\Dropbox\Projects\conference_call\output\01_download_cc\01.1_xls_2\20201009-20201012_1.xls
# (236,)
# C:\Users\jasonjia\Dropbox\Projects\conference_call\output\01_download_cc\01.1_xls_2\20201013-20201016_1.xls
# (286,)
# C:\Users\jasonjia\Dropbox\Projects\conference_call\output\01_download_cc\01.1_xls_2\20201013-20201016_2.xls
# (336,)
# ...

# %%
df_report_id_compiledadddd
# Out:
#                   0           1           2           3           4   \
# Report #  70495105.0  70525202.0  70494856.0  70495630.0  70494903.0
# Report #  70534492.0  70535008.0  70534969.0  70534535.0  70822917.0
# Report #  70532901.0  70532930.0  70525868.0  70524519.0  70526559.0
# Report #  70516476.0  70516058.0  70517812.0  70517414.0  70516647.0
# Report #  70513014.0         NaN         NaN         NaN         NaN
# ...              ...         ...         ...         ...         ...
# Report #  70834077.0  70833570.0  70834239.0  70833692.0  70834279.0
# Report #  70833511.0  70834152.0  70833787.0  70835681.0  70835892.0
# Report #  70838222.0  70835878.0  70836608.0  70837093.0  70837671.0
# Report #  70837095.0  70834772.0  70832030.0  70830926.0  70830714.0
# Report #  70839721.0  70834795.0  70834223.0  70837202.0  70834375.0
#
#                   5           6           7           8           9   ...  \
# ...

# %%
df_report_id_compiled.to_csv(outputfilepath, index = None)

# %%
# Remove duplicates and print out the length of list (number of papers)
 
        
        # chunktable = chunktable[['Date',]
        table = table.append(chunktable)

# %%
# Part 2 - Combine csv files and remvoe duplicates

# %%
csv_1_filepath = Path(r"C:\Users\jasonjia\Dropbox\Projects\conference_call\output\12_summary_statistics\report_id_01.1_xls_1.csv")
csv_2_filepath = Path(r"C:\Users\jasonjia\Dropbox\Projects\conference_call\output\12_summary_statistics\report_id_01.1_xls_2.csv")

# %%
df1 = pd.read_csv(csv_1_filepath)
df2 = pd.read_csv(csv_2_filepath)
print(df1.shape)
print(df2.shape)
# Out:
# (548084, 1)
# (40154, 1)

# %%
df = df1.append(df2)
print(df.shape)
# Out:
# (588238, 1)

# %%
df['Report #'].unique()
# Out:
# array([21044925, 21045694, 21045712, ..., 72043635, 72043709, 72043680],
#       dtype=int64)

# %%
df['Report #'].nunique()
# Out:
# 558391
